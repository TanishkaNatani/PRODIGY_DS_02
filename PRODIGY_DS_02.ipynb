# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\TANUVEDU\Downloads\Titanic-Dataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(columns="Cabin",axis=1,inplace=True)

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='Survived',data=df,palette='coolwarm',)
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.show()
# Out:
# C:\Users\TANUVEDU\AppData\Local\Temp\ipykernel_11884\1486452071.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived',data=df,palette='coolwarm',)

# %%
plt.pie(
    df['Survived'].value_counts(),
    explode=[0, 0.04],
    autopct="%1.2f%%",
    labels=['Not survived', 'Survived'],
    colors=['#ff9999', '#66b3ff']  # Example: red and blue
)
plt.title("Survival of People")
plt.show()

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
sns.countplot(x='Sex', data=df, palette='coolwarm')  # Using 'coolwarm' palette
plt.xlabel("Gender")
plt.ylabel("Number of People")
plt.show()
# Out:
# C:\Users\TANUVEDU\AppData\Local\Temp\ipykernel_11884\951425841.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=df, palette='coolwarm')  # Using 'coolwarm' palette

# %%
sns.countplot(x='Survived',hue='Sex',data=df,palette='coolwarm',)
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.show()

# %%
colors = sns.color_palette("Set2", 2)  # Change 'Set2' to any preferred palette
df[df['Sex'] == 'male'].Survived.groupby(df.Survived).count().plot(
    kind='pie',
    figsize=(3, 6),
    explode=[0, 0.05],
    autopct='%1.1f%%',
    labels=["Not survived", "Survived"],
    colors=colors
)
# Out:
# <Axes: ylabel='Survived'>

# %%
df[df['Sex'] == 'female'].Survived.groupby(df.Survived).count().plot(
    kind='pie',
    figsize=(3, 6),
    explode=[0, 0.05],
    autopct='%1.1f%%',
    labels=["Not survived", "Survived"],
    colors=['#ff9999', '#66b3ff']  # Similar colors as used before (red and blue)
)
plt.ylabel("")
plt.title("Female Survival Rate")
plt.show()

# %%
sns.countplot(x='Pclass', data=df, palette='Set2')  # Using 'Set2' color palette
plt.xlabel("Pclass")
plt.ylabel("Number of People")
plt.show()
# Out:
# C:\Users\TANUVEDU\AppData\Local\Temp\ipykernel_11884\1603666154.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Pclass', data=df, palette='Set2')  # Using 'Set2' color palette

# %%
sns.countplot(x='Survived',hue='Pclass',data=df,palette='Set2',)
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.show()

# %%
sns.catplot(x = 'Pclass', hue = 'Survived', col = 'Sex', kind = 'count', data =
df,palette='Set2' )
plt.tight_layout()

# %%
sns.countplot(x='Embarked',data=df,palette='coolwarm',)
plt.xlabel("Embarked")
plt.ylabel("Number of people")
plt.show()
# Out:
# C:\Users\TANUVEDU\AppData\Local\Temp\ipykernel_11884\641915444.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Embarked',data=df,palette='coolwarm',)

# %%
sns.countplot(x='Survived',hue='Embarked',data=df,palette='viridis',)
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.show()

# %%
fig,axes = plt.subplots(1, 2, figsize=(12, 6))
sns.countplot(x='SibSp',data=df,ax=axes[0],palette='husl')
sns.countplot(x='Parch',data=df,ax=axes[1],palette='husl')
plt.show()
# Out:
# C:\Users\TANUVEDU\AppData\Local\Temp\ipykernel_11884\1641772109.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='SibSp',data=df,ax=axes[0],palette='husl')
# C:\Users\TANUVEDU\AppData\Local\Temp\ipykernel_11884\1641772109.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Parch',data=df,ax=axes[1],palette='husl')

# %%
sns.countplot(x ='Survived', hue='SibSp',data=df,palette='viridis')
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.title("Survival population of Sibsp")
plt.show()

sns.countplot(x ='Survived',hue='Parch',data=df,palette='viridis')
plt.xticks(ticks=[0,1],labels=['Not survived','survived'])
plt.title("Survival population of Parch")
plt.xlabel("Survival status")
plt.ylabel("Number of people")
plt.show()

# %%
fig,axes = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(df['Fare'], kde=True,ax=axes[0])
sns.histplot(df['Age'].dropna(),kde=True,ax=axes[1])
plt.show()

# %%
cut_points = [ 0, 5, 12, 18, 35, 60, 100]
label_names = [ 'Infant', "Child", 'Teenager', "Young Adult", 'Adult', 'Senior']

df['Age_categories'] = pd.cut(df['Age'], bins=cut_points, labels=label_names,right=False)

age_cat_pivot = df.pivot_table(index="Age_categories", values="Survived")

colors = ['blue', 'green', 'orange', 'purple', 'pink', 'brown']

fig, ax = plt.subplots()
bars = ax.bar(age_cat_pivot.index, age_cat_pivot['Survived'], color=colors)

handles = [plt.Rectangle((0, 0), 1, 1, color=colors[i]) for i in
range(len(colors))]
ax.legend(handles, label_names)
ax.set_title('Survival Rates by Age Category')
ax.set_xlabel('Age Category')
ax.set_ylabel('Survival Rate')
plt.xticks(rotation=40)
plt.show()
# Out:
# C:\Users\TANUVEDU\AppData\Local\Temp\ipykernel_11884\1627046190.py:6: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   age_cat_pivot = df.pivot_table(index="Age_categories", values="Survived")

# %%
sns.histplot(x='Fare',hue='Survived',data=df,kde=True)
plt.legend(labels=['survived','not survived'])
plt.show()

# %%
sns.histplot(x='Age',hue='Survived',data=df,kde=True)
plt.legend(labels=['survived','not survived'])
plt.show()

# %%
df.replace({'Sex':{'male':1,'female':0},'Embarked':{'S':0,'C':1,'Q':2}}, inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  Embarked Age_categories
# 0         A/5 21171   7.2500         0    Young Adult
# 1          PC 17599  71.2833         1          Adult
# 2  STON/O2. 3101282   7.9250         0    Young Adult
# 3            113803  53.1000         0          Adult
# 4            373450   8.0500         0          Adult

# %%
df_num = df[['Fare','Parch','SibSp','Age','Sex','Pclass','Embarked','Survived']]

# %%
sns.heatmap(df_num.corr(),annot=True)
plt.show()
